# %% [markdown]
# <span style="color:green">**Поздравляю, твой проект принят!**</span>
#
# Кристина, отличная работа, получился качественный аналитический отчет. Поставленные задачи были успешно выполнены! Спасибо за обозначение корректировок. Недочёты исправлены! Надеюсь, ревью было полезным:) Желаю успехов в учебе и со следующими проектами!
#
#
# <span style="color:purple">**Привет еще раз!**</span> v2
#
# Кристина, спасибо, что доработала проект, недочёты исправлены! Однако твой код выдал ошибку в 44 ячейке. Исправь её, чтобы я принял твою работу. Дал дополнительные комментарии. Жду твою работу!
#
# Оформление комментариев оставим таким же, только обозначим номер проверки `v2`.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА 2: Исправила 42 ячейку, и поправила ось У, которая не получалась. Перед отправкой перезапустила ядро и все работает) надеюсь ничего не вылезет. Пока исправляла как то криво грузилась библиотека from skimpy import clean_columns. Один раз без !pip не загрузился совсем проект, перед отправкой запустилось и без !pip. Так и не поняла как правильно загрузить))) </b>
# </div>

# %% [markdown]
# <span style="color:purple">**Привет, Кристина!**</span>
#
# Меня зовут **Василий Удинкан** и я - ревьювер, буду проверять твой проект.
#
# К сожалению, ко мне пришел полностью пустой проект. Пришли готовую работу.

# %% [markdown]
# Привет! Приятно познакомиться😊
#
# Да лааааадно, а я так ждала комментарии.😩 Не в первый раз юпитер падает на моих проектах уже и так в лольной версии делаю. Вчера 10 раз пыталась загрузить свою тетрадку. Надеюсь эту ты увидишь

# %% [markdown]
# **Взаимно:)**
#
# <span style="color:red">К сожалению, код выдал мне ошибку в 15-й ячейке.</span> Посмотри, пожалуйста, что пошло не так. Исправь ошибку, чтобы я начал ревью. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All``.
#
# Пока расскажу о правилах оформления ревью.
#
# Если не против, я буду обращаться к тебе на "ТЫ". Если это неприемлемо, обязательно напиши мне в комментариях – мы прейдем на "ВЫ".
#
# Обрати внимание, я буду выделять свои комментарии цветом, в зависимости от того, какие действия, важность и особенности тебя ждут в процессе проверки.
#
# <div class="alert alert-block alert-success">
#
#
# **Комментарий ревьювера (все отлично)**
#
# Такими комментариями я буду помечать хорошо проделаную работу, а так же хорошо проделаную работу над ошибками.
# </div>
#
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# После таких комментариев ничего исправлять не нужно, но я дам рекомендации на будущее и подскажу, что можно улучшить.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера (недочет, который нужно доработать)**
#
# Если ты видишь такой комментарий, значит я указываю тебе на недочёт, его нужно исправить. Без такого исправления я не приму твою работу:)
# </div>
#
# **Пожалуста, не удаляй мои комментарии. При повторной проверке, я буду ориентироваться на них.**
#
# <span style="color:blue"> Можешь под моими комментариями оставлять свои, в которых опиши свои исправления. Это облегчит процесс проверки и мне, и тебе:) Например, вот так:</span>
#
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: </b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: Привет! Я в недоумении конечно. В моей локальной версии все работает. Я не могу загрузить свою тетрадку на платформу, чтобы проверить работоспобность кода, потому что отправляется в итоге пустая тетрадка (как было в первый раз). А когда отправляю тетрадку через кнопку "загрузить и отправить" в итоге не понятно отработает платформа или нет. В лольной версии я работаю в окружении Яндекса и мне не понять, почему такие ошибки возникают. </b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: проверь пожалуйста, перед отправкой весь код отработал, пришлось убрать функцию .eval() и переписать 15 ячейку. Так и не разобралась в чем была проблема 😨 хотя 17 ячейка работает с этим методом </b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Код работает, присутпаем к ревью!
#
# </div>

# %% [markdown]
# # Исследование по приоритезации гипотез и запуск А/В теста

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Вы — аналитик крупного интернет-магазина. Вместе с отделом маркетинга вы подготовили список гипотез для увеличения выручки.
#
# Цель проекта:
# - приоритизировать 9 представленных гипотез, определить наиболее перспективные
# - проанализировать результаты проведенного А/В теста, принять решение по результатам анализа.
#
# План проекта:
# 1. Предобработка данных, на этом этапе проанализируем:
#     * структуру представленных датафреймов,
#     * корректность названия столбцов,
#     * размер датафреймов,
#     * тип данных в датафреймах,
#     * проверка периода, за который представлены данные,
#     * проверка на дубликаты в датафреймах.
#
# 2. Приоритизация представленных гипотез:
#     * методом ICE
#     * методом RICE
#     * вывод по разделу
#
# 3. Анализ результатов А/В теста, для этого необходимо проанализровать:
#     * кумулятивную выручку по группам
#     * кумулятивный средний чек по группам
#     * относительное изменение кумулятивного среднего чека группы B к группе A
#     * кумулятивное среднее количество заказов на посетителя по группам
#     * относительное изменение кумулятивного среднего количества заказов на посетителя группы B к группе A
#     * количество заказов по пользователям
#     * стоимости заказов по пользователям
#     * определить аномальных пользователей (/ заказов) и границу определения пользователя (/ заказа) "аномальным" (если они есть)
#     * статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным
#     * статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным
#     * статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным
#     * статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным
#     * вывод по разделу
#
# 4. Сформулировать выводы по результатам А/В теста и принять решение о продолжении или прикращении теста.
# 5. Общий вывод о проделанной работе.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера (недочет, который нужно доработать)**
#
# К описанию проекта стоит добавить описание этапов исследования.
#
# _________________
#
# **Почему это важно?** Когда ты будешь в будущем выполнять тестовые задания, просто скопировав присланную тебе задачу и не составив плана, ты можешь смутить будущего работодателя. А грамотно сконфигурированный план покажет тебя как ответсвенного и усидчивого специалиста. Также такой подход научит тебя структурировать исследование и не путаться при работе с большими проектами.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: Поняла, исправила </b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера v2 (все отлично)**
#
# Хорошее введение, понятно чему посвящена твоя работа и какие этапы содержит.
# </div>

# %% [markdown]
# ## Загрузка данных и подготовка их к анализу

# %%
import pandas as pd
import numpy as np
import math as mth
from scipy import stats as st
import datetime as dt
from matplotlib import pyplot as plt

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Правильно, что импортируешь необходимые библиотеки в первой ячейке. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет настроить свое окружение при необходимости.
# </div>

# %%
#!pip install skimpy
from skimpy import clean_columns

# %%
try:
    hypothesis, orders, visitors = (
        pd.read_csv('/datasets/hypothesis.csv'), 
        pd.read_csv('/datasets/orders.csv'), 
        pd.read_csv('/datasets/visitors.csv'), 
    )
except:
    hypothesis, orders, visitors = (
        pd.read_csv('https://code.s3.yandex.net/datasets/hypothesis.csv'),
        pd.read_csv('https://code.s3.yandex.net/datasets/orders.csv'),
        pd.read_csv('https://code.s3.yandex.net/datasets/visitors.csv'),
    )

# %%
# посмотрим на первые 5 строк каждого фрейма
display(
    hypothesis.head(5),
    orders.head(5),
    visitors.head(5),
)
# Out:
#                                           Hypothesis  Reach  Impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
#
#    Confidence  Efforts
# 0           8        6
# 1           4       10
# 2           7        3
# 3           3        8
# 4           1        1
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
#          date group  visitors
# 0  2019-08-01     A       719
# ...

# %% [markdown]
# Структура датасета **hypothesis**:
# * Hypothesis — краткое описание гипотезы;
# * Reach — охват пользователей по 10-балльной шкале;
# * Impact — влияние на пользователей по 10-балльной шкале;
# * Confidence — уверенность в гипотезе по 10-балльной шкале;
# * Efforts — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
# Структура датасета **orders**:
# * transactionId — идентификатор заказа;
# * visitorId — идентификатор пользователя, совершившего заказ;
# * date — дата, когда был совершён заказ;
# * revenue — выручка заказа;
# * group — группа A/B-теста, в которую попал заказ.
#
# Структура датасета **visitors**:
# * date — дата;
# * group — группа A/B-теста;
# * visitors — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# При просмотре первых строк датафреймов обнаружено, что в датафрейме hypothesis и orders названия столбцов содержат заглавные буквы. Для удобства дальнейшей работы привидем названия столбцов к стилю Snake Case.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# **Комментарий ревьювера (все отлично)**
#
# Здорово, что даешь вывод по итогам шага.
# </div>

# %%
hypothesis = clean_columns(hypothesis)
orders = clean_columns(orders)
# Out:
# 5 column names have been cleaned
# 2 column names have been cleaned

# %%
# размер датафреймов
display(
    'Датафрейм со списком гипотез состоит из {} строк и {} столбцов'.format(hypothesis.shape[0], hypothesis.shape[1]),
    'Датафрейм с информацией о заказах состоит из {} строк и {} столбцов'.format(orders.shape[0], orders.shape[1]),
    'Датафрейм с данными о количестве посетителей состоит из {} строк и {} столбцов'.format(visitors.shape[0], visitors.shape[1])
)
# Out:
# 'Датафрейм со списком гипотез состоит из 9 строк и 5 столбцов'
# 'Датафрейм с информацией о заказах состоит из 1197 строк и 5 столбцов'
# 'Датафрейм с данными о количестве посетителей состоит из 62 строк и 3 столбцов'

# %%
# выводим информацию о каждом столбце датафрейма
hypothesis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hypothesis  9 non-null      object
#  1   reach       9 non-null      int64
#  2   impact      9 non-null      int64
#  3   confidence  9 non-null      int64
#  4   efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  1197 non-null   int64
#  1   visitor_id      1197 non-null   int64
#  2   date            1197 non-null   object
#  3   revenue         1197 non-null   int64
#  4   group           1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB

# %%
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %% [markdown]
# Пропусков в столбцах датафреймов не обнаружено.
#
# При просмотре типов данных в датафреймах обнаружено, что дата указана в формате object. Заменим типа даты на нужный формат datetime.

# %%
orders['date'] = orders['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))

# %%
visitors['date'] = visitors['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Даты преведены к соответствующему типу👍
# </div>

# %%
display(
    'Минимальная дата начала отслеживания информации о заказах - {}'.format(orders['date'].min()),
    'Максимальная дата начала отслеживания информации о заказах - {}'.format(orders['date'].max())
)
# Out:
# 'Минимальная дата начала отслеживания информации о заказах - 2019-08-01 00:00:00'
# 'Максимальная дата начала отслеживания информации о заказах - 2019-08-31 00:00:00'

# %%
display(
    'Минимальная дата с информацией о посещении посетителей - {}'.format(visitors['date'].min()),
    'Максимальная дата с информацией о посещении посетителей - {}'.format(visitors['date'].max())
)
# Out:
# 'Минимальная дата с информацией о посещении посетителей - 2019-08-01 00:00:00'
# 'Максимальная дата с информацией о посещении посетителей - 2019-08-31 00:00:00'

# %%
display(
    'Количество полных дубликатов в датафрейме со списком гипотез {}'.format(hypothesis.duplicated().sum()),
    'Количество полных дубликатов в датафрейме с информацией о заказах {}'.format(orders.duplicated().sum()),
    'Количество полных дубликатов в датафрейме  данными о количестве посетителей {}'.format(visitors.duplicated().sum()),
)
# Out:
# 'Количество полных дубликатов в датафрейме со списком гипотез 0'
# 'Количество полных дубликатов в датафрейме с информацией о заказах 0'
# 'Количество полных дубликатов в датафрейме  данными о количестве посетителей 0'

# %% [markdown]
# После первичного анализа и предобработки данных можно сделать следующие выводы:
# * Предоставлены 3 датафрейма - список гипотез, данные с информацией о заказах, данные о количестве посетителей.
# * Размер датафреймов: список гипотез включает в себя 9 строк и 5 столбцов, данные с информацией о заказах - 1197 строк и 5 столбцов, данные о количестве посетителей - 62 строк и 3 столбцов.
# * Пропущенных значений в датафреймах не обнаружено.
# * Выявлено, что в датафреймах была отображена дата в некорректном формате. Для дальнейшего анализа данные столбцы приведены в корректный формат, так же было приведено название столбцов к стилю Snake Case для удобства дальнейшей работы.
# * Явных дубликатов в датафреймах не обнаружено.
# * Предоставлена информация об истории покупок пользователей и данных о количестве посетителей с 1 августа 2019 г. по 31 августа 2019 г.

# %% [markdown]
# ## Приоритизация гипотез

# %% [markdown]
# В датафрейме hypothesis представлено 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами Reach, Impact, Confidence, Effort.
#
# **Задачи**
# 1. Примените фреймворк ICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# 2. Примените фреймворк RICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# 3. Укажите, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объясните, почему так произошло.

# %% [markdown]
# ### ICE

# %% [markdown]
# ICE это акроним из следующих слов:
# * Impact – Какое влияние внедрение этой инициативы окажет на пользователя?
# * Confidence – Насколько мы уверены, что эта инициатива подтвердит нашу гипотезу и позволит добиться желаемого результата?
# * Ease – Насколько легко ее внедрить? Какие потребуются затраты и ресурсы?

# %%
hypothesis['ICE'] = round((hypothesis['impact'] * hypothesis['confidence']) / hypothesis['efforts'], 2)

# %%
pd.set_option('display.max_colwidth', 200)
hypothesis[['hypothesis', 'ICE']].sort_values(by='ICE', ascending=False)
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Наиболее перспективными согласно методу ICE по приоритезации гипотез выявлены:
# 1. Запустить акцию, дающую скидку на товар в день рождения.
# 2. Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей.
# 3. Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.
# 4. Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию.
#
# Первая гипотеза - самая перспективная (16,2 балла), дальше идут гипотезы 2, 3, 4.
#
# Менее перспективные гипотезы:
# * Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей.
# * Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар.
# * Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов.
# * Запустить собственную службу доставки, что сократит срок доставки заказов.

# %% [markdown]
# Один из минусов данной модели приоритизации состоит в том, что разные люди могут оценивать одну и ту же инициативу совершенно по-разному. Модель ICE дает систему относительной приоритизации, а не точных подсчетов, основанных на данных.

# %% [markdown]
# ### RICE

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# Правильно RICE:)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: Поправила 😅 </b>
# </div>

# %% [markdown]
# RICE - это аббревиатура от четырех факторов, которые предлагается использовать для оценки каждой идеи проекта.
#
# Фреймворк RICE состоит из четырёх компонент:
# * Reach — скольких пользователей затронет изменение, которое вы хотите внести;
# * Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# * Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# * Efforts — сколько стоит протестировать эту гипотезу.
#
# Основное отличие от метода ICE стоит в том, что метод RICE учитывает оценку скольких пользователей затронет изменение.

# %%
hypothesis['RICE'] = round(hypothesis.eval('(reach * impact * confidence) / efforts'), 2)

# %%
hypothesis[['hypothesis', 'reach', 'RICE']].sort_values(by='RICE', ascending=False)
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# Наиболее перспективными согласно методу ICE по приоритезации гипотез выявлены:
# 1. Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.
# 2. Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа.
# 3. Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей.
# 4. Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию.
#
# Первая гипотеза - самая перспективная (112 баллов), дальше со значительным отрывом идут гипотезы 2, 3, 4.
#
# Менее перспективные гипотезы:
# * Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов.
# * Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей.
# * Запустить собственную службу доставки, что сократит срок доставки заказов.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Все верно, охват меняет приоритезацию. Отличие фреймворков определено.
# </div>

# %% [markdown]
# #### Выводы:

# %% [markdown]
# При оценке гипотез методом ICE наиболее перспективные гипотезы:
# * Запустить акцию, дающую скидку на товар в день рождения.
# * Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей.
# * Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.
# * Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию.
#
# При оценке гипотез методом RICE наиболее перспективные гипотезы:
# * Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.
# * Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа.
# * Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей.
# * Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию.
#
# Имеется 2 совпадения в результатах - "Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей" и "Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию".
#
# Различия в оценке наиболее перспективных гипотезах в разнице параметра Reach (охват пользователей, которых затронет изменение).
#
# В 10 баллов по охвату оценена гипотеза "Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок". По этой причине данная гипотеза лидирует при использовании метода RICE.
#
# Важно учитывать скольких пользователей затронут изменения, в связи с этим имеет смысл проанализировать следующие гипотезы:
# 1. Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок, т.к. данная гипотеза затронет всех пользователей интернет-магазина
# 2. Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа. Не стоит отметать и эту гипотезу, т.к. она затронет 80% пользователей интернет-магазина.
# 3. Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар. Не стоит отметать и эту гипотезу, т.к. она затронет 80% пользователей интернет-магазина.

# %% [markdown]
# ## Анализ A/B-теста

# %% [markdown]
# Вы провели A/B-тест и получили результаты, которые описаны в датафреймах orders и visitors
#
# **Задача**
#
# Проанализируйте A/B-тест:
# 1. Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.
# 2. Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.
# 3. Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.
# 4. Постройте график кумулятивного среднего количества заказов на посетителя по группам. Сделайте выводы и предположения.
# 5. Постройте график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Сделайте выводы и предположения.
# 6. Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.
# 7. Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.
# 8. Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.
# 9. Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.
# 10. Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Сделайте выводы и предположения.
# 11. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.
# 12. Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделайте выводы и предположения.
# 13. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.

# %% [markdown]
# Так как не известно проводился ли А/А тест и его результаты, то перед анализом результатов теста проверим распределение пользователей в группах, а именно не определили ли случайно одного пользователя и в группу А и в группу В.

# %%
len(orders['visitor_id'].unique())
# Out:
# 1031

# %%
len(orders.query('group == "A"')['visitor_id'].unique())
# Out:
# 503

# %%
len(orders.query('group == "B"')['visitor_id'].unique())
# Out:
# 586

# %%
group_a = list(orders.query('group == "A"')['visitor_id'].unique())
group_b = list(orders.query('group == "B"')['visitor_id'].unique())
group_a_b = [] 

for i in group_b:
    if i in group_a:
        group_a_b.append(i)

len(group_a_b)
# Out:
# 58

# %% [markdown]
# Всего в датафрейме представлены данные о 1031 уникальном пользователе, из них 503 пользователя в группе А, а 586 пользователей в группе В.
#
# При этом обнаружено совпадение 58 пользователей - столько человек находится одновременно в группе А и в группе В.
#
# Исключить этих пользователей можно, но это не даст весомого результата, т.к. в датафрейме с данными о количестве поситетелей данные предоставлены в агерегированном формате и вычленить информацию количество посещений этих 58 пользователей не возможно.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Молодец, что проверила пересечение групп. Такая проверка была необходима. так как при АВ тестировании могут быть ошибки при логировании и распределении пользователей по группам. Согласен с решением и аргументацией их оставить.
# </div>

# %% [markdown]
# ### Анализ кумулятивной выручки по группам

# %%
date_groups = orders[['date', 'group']].drop_duplicates()

# %%
# создаем переменную содержащую дату, группу А/В теста, число уникальных заказов в 
# группе теста в указанную дату включительно, число уникальных пользователей, совершивших 
# хотя бы 1 заказ в группе в указанную дату включительно, суммарную выручку с заказов
# в группе теста в указанную дату включительно 

orders_aggregated = date_groups.apply(
    lambda x: orders[
        np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group']
        )
    ].agg(
        {
            'date' : 'max',
            'group' : 'max',
            'transaction_id' : 'nunique',
            'visitor_id' : 'nunique',
            'revenue' : 'sum'
        }
    ),
    axis=1,
).sort_values(by=['date', 'group'])

# %%
# создадим переменную содержащую дату, группу А/В теста, количество уникальных 
# пользователей в группе теста в казанную дату включительно

visitors_aggregated = date_groups.apply(
    lambda x: visitors[
        np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group']
        )
    ].agg(
        {
            'date' : 'max',
            'group' : 'max',
            'visitors' : 'sum'
        }
    ),
    axis=1
).sort_values(by=['date', 'group'])

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Кумулятивные данные собраны.
# </div>

# %%
# Объединим 2 переменные orders_aggregated и visitors_aggregated по столбцам date и group

cumulative_data = orders_aggregated.merge(
    visitors_aggregated, left_on=['date', 'group'], right_on=['date', 'group']
)
cumulative_data.columns = [
    'date', 
    'group',
    'orders',
    'buyers',
    'revenue',
    'visitors'
]

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulative_revenue_a = cumulative_data[cumulative_data['group'] == 'A'][['date', 'revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе В
cumulative_revenue_b = cumulative_data[cumulative_data['group'] == 'B'][['date', 'revenue', 'orders']]

# %%
plt.figure(figsize=(15,5))

# Строим график выручки группы А
plt.plot(cumulative_revenue_a['date'], cumulative_revenue_a['revenue'], color='mediumaquamarine', label='A')

# Строим график выручки группы B
plt.plot(cumulative_revenue_b['date'], cumulative_revenue_b['revenue'], color='lightsalmon', label='B')

plt.xlabel('Дата наблюдения') 
plt.ylabel('Выручка, в млн. у.е.') 
plt.title('Кумулятивная выручка по дням в группах')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Визуализация на хорошем уровне. Здорово, что уделяешь внимание оформлению графиков. Единственное, я бы смело увеличил их размер.
#
# Предлагаю изучить интересные методы по визуализации. Прикрепляю несколько интересных ссылок:
#
#
#
# https://coderlessons.com/tutorials/python-technologies/izuchai-siborna/siborn-kratkoe-rukovodstvo
#
# https://tproger.ru/translations/python-data-vizualization/
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: благодарю за информацию, обязательно ознакомлюсь. Увеличила размер, подскажи пожалуйста, так лучше? Так теперь видно все дни теста. </b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера v2 (все отлично)**
#
# Да, так лучше)
# </div>

# %% [markdown]
# На протяжении первых 14 дней теста выручка плавно росла в обеих группах и различалась не сильно. Начиная с 16 дня теста выручка группы В имела более интенсивный рост, чем выручка группы А.
#
# Возможно на результатах анализа могли сказаться слишком большие чеки некоторых заказов.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Резкий рост обнаружен👍
# </div>

# %% [markdown]
# ### Анализ кумулятивного среднего чека по группам

# %%
plt.figure(figsize=(15,5))

# Строим график среднего чека группы А
plt.plot(cumulative_revenue_a['date'], cumulative_revenue_a['revenue'] / cumulative_revenue_a['orders'], color='mediumaquamarine', label='A')

# Строим график среднего чека группы В
plt.plot(cumulative_revenue_b['date'], cumulative_revenue_b['revenue'] / cumulative_revenue_b['orders'], color='lightsalmon', label='B')

plt.xlabel('Дата наблюдения') 
plt.ylabel('Средний чек, в тыс. у.е.') 
plt.title('Кумулятивное значение среднего чека по дням в группах')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Кумулятивное значение среднего чека колеблется на всем анализируемом периоде, однако начиная с 18 дня наблюдения средний чек группы В вырос на 30% по сравнению с группой А, а в дальнешем имел тенденцию к сокращению среднего чека, когда группа А имела тенденцию к плавному росту среднего чека.
#
# Вероятно на результатах могли сказаться разовые крупные покупки, которые искажают результат.
#
# Вероятно необходим дополнительный анализ выбросов, которые так сильно искажают результаты.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Согласен.
# </div>

# %% [markdown]
# ### Анализ относительного изменения кумулятивного среднего чека группы В к группе А

# %%
merged_cumulative_revenue = (
    cumulative_revenue_a
    .merge(cumulative_revenue_b, left_on=['date'], right_on=['date'], suffixes=['_a', '_b'])
)

# %%
plt.figure(figsize=(15,5))
plt.plot(merged_cumulative_revenue['date'], (merged_cumulative_revenue['revenue_b'] / merged_cumulative_revenue['orders_b']) / (merged_cumulative_revenue['revenue_a'] / merged_cumulative_revenue['orders_a']) - 1,color='lightseagreen')

plt.xlabel('Дата наблюдения') 
plt.ylabel('Средний чек, в тыс. у.е.') 
plt.title('Относительное различие кумулятивного среднего чека группы В к группе А')
plt.grid(True)
plt.xticks(rotation=45)
plt.axhline(y=0, color='black', linestyle='--') 
plt.show()

# %% [markdown]
# На график относительного различия среднего чека группы В к группе имеются "всплески" - 6, 8 и 19 дни теста. Вероятно в эти даты были совершены аномальные заказы с крупными чеками.

# %% [markdown]
# ### Анализ относительного изменения кумулятивного среднего количества заказов на посетителя по группам

# %%
cumulative_data['conversion'] = cumulative_data['orders'] / cumulative_data['visitors']

# %%
cumulative_data_a = cumulative_data[cumulative_data['group'] == 'A']
cumulative_data_b = cumulative_data[cumulative_data['group'] == 'B']

# %%
plt.figure(figsize=(15,5))
plt.plot(cumulative_data_a['date'], cumulative_data_a['conversion'], color='mediumaquamarine', label='A')
plt.plot(cumulative_data_b['date'], cumulative_data_b['conversion'], color='lightsalmon', label='B')

plt.xlabel('Дата наблюдения') 
plt.ylabel('Количество заказов на посетителя') 
plt.title('Кумулятивное значение среднего количества заказов на посетителя по дням в группах')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# В начале теста у группы А наблюдался всплеск среднего количества заказов - 3 дня теста, далее наблюдалось сильное снижение среднего количества заказов до 9 дня теста. Начиная с 9 дня теста и до конца теста наблюдалось колебание данного показателя около отметки 0,3.
#
# У группы В так так же наблюдался всплеск вначале теста - во 2 день теста, который в последующем так же пошел на спад до 4 дня теста (но не такой сильный как у группы А). Однако начиная с 4 дня теста наблюдался ежедневный рост среднего количества заказов до 9 дня теста. Во второй половине периода теста средний чек группы В имел тенденцию сокращению данного показателя.
#
# На результаты анализа могло повлиять:
# * аномальное количество заказов пользователей,
# * неоднородное деление трафика по группам,
# * возможное попадание пользователей и в группу А и в группу В одновременно, а если это еще окажутся пользователи с аномальными значениями, то они исказят значение среднего, а соответственно и результаты теста.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Можно добавить, что к середине теста показатель стабилизировался в том числе для группы В.
# </div>

# %% [markdown]
# ### Анализ относительного изменения кумулятивного среднего количества заказов на посетителя группы В к группе А

# %%
merged_cumulative_conversions = (
    cumulative_data_a[['date', 'conversion']]
    .merge(cumulative_data_b[['date', 'conversion']], left_on=['date'], right_on=['date'], suffixes=['_a', '_b'])
)

# %%
plt.figure(figsize=(15,5))
plt.plot(merged_cumulative_conversions['date'], (merged_cumulative_conversions['conversion_b'] / merged_cumulative_conversions['conversion_a']) - 1,color='lightseagreen')

plt.xlabel('Дата наблюдения') 
plt.ylabel('Среднее количество заказов') 
plt.title('Относительное различие кумулятивного среднего количества заказов на посетителя группы В к группе А')
plt.grid(True)
plt.xticks(rotation=45)
plt.axhline(y=0, color='black', linestyle='--') 
plt.show()

# %% [markdown]
# Начиная с 6 дня теста группа В лидирует по среднему количеству заказов на посетителя, однако начиная с середины теста (17 дня) среднее количество заказов группы В имеет тенденцию к снижению данного показателя.
#
# На результаты анализа также могло повлиять:
# * аномальное количество заказов пользователей,
# * неоднородное деление трафика по группам,
# * возможное попадание пользователей и в группу А и в группу В одновременно, а если это еще окажутся пользователи с аномальными значениями, то они исказят значение среднего, а соответственно и результаты теста.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Здорово, что даешь комментарии под графиками👍
# </div>

# %% [markdown]
# ### Анализ количества заказов по пользователям и выбор границы для определения аномальных пользователей

# %%
orders_by_users = (
    orders
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id' : 'nunique'})
    .sort_values(by='transaction_id', ascending=False)
)
orders_by_users.columns = ['user_id', 'orders']

# %%
fig = plt.figure(figsize=(15, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1 = plt.hist(orders_by_users['orders'], color='mediumaquamarine')
plt.xlabel('Количество заказов') 
plt.ylabel('Количество пользователей') 

x_values = pd.Series(range(0, len(orders_by_users)))

ax2 = fig.add_subplot(1, 2, 2)
ax2 = plt.scatter(x_values, orders_by_users['orders'], color='mediumaquamarine')
plt.xlabel('Количество пользователей') 
plt.ylabel('Количество заказов') 
plt.ylim([0, 8])
plt.show()

# %% [markdown]
# Из представленных диаграмм видно, что большинство пользователей делало 1 заказ, при этом имеется малая часть пользователей которые делали и от 2 и больше заказов.

# %%
np.percentile(orders_by_users['orders'], [90, 95, 99])
# Out:
# array([1., 2., 4.])

# %% [markdown]
# Не более 5% пользователей совершали более 2 заказов. И не более 1% пользователей - больше 4 заказов.
#
# *Определим границу определения аномальных пользователей - более 2-х заказов.*

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Отлично, перцентили количества заказов на пользователя рассчитаны верно. Согласен с выбранной границей.
# </div>

# %% [markdown]
# ### Анализ стоимости заказов по пользователям и выбор границы для определения аномальных пользователей

# %%
fig = plt.figure(figsize=(15, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1 = plt.hist(orders['revenue'], color='mediumaquamarine', bins=100)
plt.xlabel('Стоимость заказов') 
plt.ylabel('Количество пользователей')

x_values = pd.Series(range(0, len(orders['revenue'])))

ax2 = fig.add_subplot(1, 2, 2)
ax2 = plt.scatter(x_values, orders['revenue'], color='mediumaquamarine')
plt.xlabel('Количество пользователей') 
plt.ylabel('Стоимость заказов') 
plt.ylim([0, 100000])
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# Можно увеличить масштаб графика, не учитывая аномально большие значения при помощи:
#
#     plt.ylim([0, верхняя граница по оси Y])
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: скорректироала в п. 4.6 все получилось, а тут при указании границ (любых вариантов) пустой график отображается (нет ни одного значения). Не совсем понимаю почему в одном случае работает, а в другом нет 😲😐 Для примера закомментирую код, который указывала, посмотри пожалуйста.</b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера v2 (что можно улучшить)**
#
# Дело в том, что на оси другой числовой формат. Попробуй вставить значение равное, например, 100000.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА 2: поняла, получилось. Спасибо за подсказку) </b>
# </div>

# %% [markdown]
# Сумма большинства заказов меньше 20 000 у.е. При этом наблюдается наличие заказа стоимостью свыше 120 тыс. у.е. Заказ на 120 тыс. у.е. в интернет магазине выглядит весьма аномально.
# Наличие такого заказа в тестировании может существенно исказить значение теста.
#
# Так же можно отметить наличие большого количества заказов (около 1 200 заказов) стоимостью около 20 000 у.е. Однако пока не ясно какой это процент пользователей.

# %%
np.percentile(orders['revenue'], [90, 95, 99])
# Out:
# array([18168. , 28000. , 58233.2])

# %% [markdown]
# Не более 5% пользователей совершали заказы стоимостью более 28 000 у.е. И не более 1% пользователей - больше 58 233.2 у.е.
#
# *Определим границу определения аномальных пользователей - более 30 000 у.е.*

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Отлично, перцентили величины заказов рассчитаны верно. По границе тоже согласен.
# </div>

# %% [markdown]
# ### Определение различий в среднем количестве заказов между группами по "сырым" данным

# %% [markdown]
# Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» (с аномальными значениями) данным.

# %% [markdown]
# Для определения различий между группами применим критерий Манна-Уитни, он используется для сравнения различий между двумя выборками, когда распределение выборки не является нормальным.
#
# ```
# H_0: Среднее количество заказов группы А равно среднему количеству заказов группы В
# H_1: Среднее количество заказов группы А НЕ одинаково среднему количеству заказов группы В
# alpha = 0.05
# ```

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Основные параметры проверки отражены. Гипотезы верно сформулированы.
# </div>

# %%
orders_by_users_a = (
    orders[orders['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
orders_by_users_a.columns = ['visitor_id', 'orders']

orders_by_users_b = (
    orders[orders['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
orders_by_users_b.columns = ['visitor_id', 'orders']

sampleA = (
    pd.concat(
        [orders_by_users_a['orders'], 
         pd.Series(0, 
                   index=np.arange(visitors[visitors['group'] == 'A']['visitors'].sum() - len(orders_by_users_a['orders'])), 
                   name='orders')]
        ,axis=0)
)
    
sampleB = (
    pd.concat(
        [orders_by_users_b['orders'],
         pd.Series(0, 
                   index=np.arange(visitors[visitors['group'] == 'B']['visitors'].sum() - len(orders_by_users_b['orders'])), 
                   name='orders')],
        axis=0)
)
    
alpha = .05

results = st.mannwhitneyu(sampleA, sampleB)

print('P-value -', round(results.pvalue, 5))

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя'
    ) 

print("Относительны прирост среднего количества заказов группы В к группе А {0:.3%}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# P-value - 0.01679
# Отвергаем нулевую гипотезу: разница статистически значима
# Относительны прирост среднего количества заказов группы В к группе А 13.808%

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# Почему ты повторно формируешь кумулятивные данные? В начале анализа АВ теста ты уже собрала всю необходимую информацию в `cumulative_data`.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: запуталась в теории в курсе 😒 вроде разобралась и исправила. затупила в значениях cumulative_data и выходил другой % - (14,3%), потом поняла что там кумулятивные значения с накоплением, а не посещения по дням. </b>
# </div>

# %% [markdown]
# Из представленных реультатов можно сделать следующие выводы:
# 1. Отвергаем нулевую гипотезу о равенстве среднего количества заказов между группами А и В. Средние не равны, обнаружена статистически значимая разница.
# 2. Среднее количество заказов группы В на 13,8% больше среднего количества заказов группы А.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Согласен. Группа B лучше по результатам.
# </div>

# %% [markdown]
# ### Определение различий в среднем чеке между группами по "сырым" данным

# %% [markdown]
# ```
# H_0: Средний чек группы А равен среднему чеку группы В
# H_1: Средний чек группы А НЕ равен среднему чеку группы В
# alpha = 0.05
# ```

# %%
results = st.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])

print('P-value -', round(results.pvalue, 5))

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя')
    
print('Относительное различие среднего чека группы В к группе А {0:.3%}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# P-value - 0.72929
# Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя
# Относительное различие среднего чека группы В к группе А 25.871%

# %% [markdown]
# P-value больше 0.05% - статистически значимых отличий в среднем чеке между группами нет.
#
# Кроме того, относительное различие среднего чека между группами 25,9%, не смотря на это статистически значимого отличия не обнаружено.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Ты верно сделала вывод, что значимых различий в среднем чеке нет.
# </div>

# %% [markdown]
# ### Определение различий в среднем количестве заказов между группами по "очищенным" данным

# %% [markdown]
# ```
# H_0: Среднее количество заказов группы А равно среднему количеству заказов группы В
# H_1: Среднее количество заказов группы А НЕ одинаково среднему количеству заказов группы В
# alpha = 0.05
# ```

# %%
users_with_many_orders = pd.concat(
    [
        orders_by_users_a[orders_by_users_a['orders'] > 2]['visitor_id'],
        orders_by_users_b[orders_by_users_b['orders'] > 2]['visitor_id']
    ],
    axis=0
)

users_with_expensive_orders = orders[orders['revenue'] > 30000]['visitor_id']

abnormal_users = (
    pd.concat([users_with_many_orders, users_with_expensive_orders],axis=0)
    .drop_duplicates()
    .sort_values()
)

sample_a_filtered = pd.concat(
    [
       orders_by_users_a[
           np.logical_not(orders_by_users_a['visitor_id'].isin(abnormal_users))
       ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitors[visitors['group'] == 'A']['visitors'].sum() - len(orders_by_users_a['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sample_b_filtered = pd.concat(
    [
       orders_by_users_b[
           np.logical_not(orders_by_users_b['visitor_id'].isin(abnormal_users))
       ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitors[visitors['group'] == 'B']['visitors'].sum() - len(orders_by_users_b['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

results = st.mannwhitneyu(sample_a_filtered, sample_b_filtered)

print('P-value -', round(results.pvalue, 5))

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя')
    
print('Относительное различие среднего количества заказов группы В к группе А {0:.3%}'.format(sample_b_filtered.mean()/sample_a_filtered.mean()-1))
# Out:
# P-value - 0.01334
# Отвергаем нулевую гипотезу: разница статистически значима
# Относительное различие среднего количества заказов группы В к группе А 17.155%

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера v2 (недочет, который нужно доработать)**
#
# Ошбика в коде.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА 2 : Поправила </b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера v3 (все отлично)**
#
# 👍
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (что можно улучшить)**
#
# Для оценки потерь данных рекомендуется посчитать аномальных пользователей.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: Добавила и одновременно задумалась, а допустимо ли различие в 15% между группами. Не получится ли так, что за счет бОльшего количества данных та или иная группа будет перевешивать и искажать результаты? и по 7% аномальных данных допустимо для удаления? Ранее в проектах нам говорили о допустимости удаления данных не более 5% </b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера v2 (все отлично)**
#
# Допустимо, главное чтобы наблюдений было достаточно для того, чтобы делать выводы. В теории быть пропорции групп даже 90 на 10, только потребуется гораздо больше времени для проведения теста, потому что потребуется репрезентативное количество наблюдений.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА: Благодарю за разъяснение </b>
# </div>

# %%
print('Количество аномальных пользователей группы А:')
print('    - сумма заказов больше 30 000 у.е. - {}'.format(len(orders[(orders['revenue'] > 30000) & (orders['group'] == "A")])))
print('    - количество заказов больше 2 - {}'.format(len(orders_by_users_a[orders_by_users_a['orders'] > 2]['visitor_id'])))
print('Итого аномальных пользователей группы А - {}'.format(len(orders[(orders['revenue'] > 30000) & (orders['group'] == "A")]) + len(orders_by_users_a[orders_by_users_a['orders'] > 2]['visitor_id'])))
print()
print('Количество аномальных пользователей группы B:')
print('    - сумма заказов больше 30 000 у.е. - {}'.format(len(orders[(orders['revenue'] > 30000) & (orders['group'] == "B")])))
print('    - количество заказов больше 2 - {}'.format(len(orders_by_users_b[orders_by_users_b['orders'] > 2]['visitor_id'])))
print('Итого аномальных пользователей группы В - {}'.format(len(orders[(orders['revenue'] > 30000) & (orders['group'] == "B")]) + len(orders_by_users_b[orders_by_users_b['orders'] > 2]['visitor_id'])))
# Out:
# Количество аномальных пользователей группы А:
#     - сумма заказов больше 30 000 у.е. - 23
#     - количество заказов больше 2 - 13
# Итого аномальных пользователей группы А - 36
#
# Количество аномальных пользователей группы B:
#     - сумма заказов больше 30 000 у.е. - 31
#     - количество заказов больше 2 - 11
# Итого аномальных пользователей группы В - 42

# %% [markdown]
# Ранее мы уже определили, что всего в датафрейме представлены данные о 1 031 уникальном пользователе, из них
# * 503 пользователя в группе А (из них 36 аномальных - 7,15%),
# * 586 пользователей в группе В (из них 42 аномальных - 7,16%).

# %% [markdown]
# Из представленных реультатов можно сделать следующие выводы:
# 1. При очистке данных от аномальных пользователей было потеряно по 7% данных с каждой группы.
# 2. Изначально перевес по количеству пользователей на 16% был у группы В (в этой группе оказалось больше пользователей чем в группе А).
# 3. После удаления номальных пользователей распределение по группам составило - 467 пользователей в группе А, и 544 пользователя в группе В. Пользователей в группе В по прежнему больше на 16% чем пользователей в группе А.
# 4. Отвергаем нулевую гипотезу о равенстве среднего количества заказов между группами А и В по очищенным данным. Средние не равны, обнаружена статистически значимая разница.
# 5. Среднее количество заказов группы В на 17,15% больше среднего количества заказов группы А.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Всё верно, значимые различия по-прежнему есть.
# </div>

# %% [markdown]
# ### Определение различий в среднем чеке между группами по "очищенным" данным

# %% [markdown]
# ```
# H_0: Средний чек группы А равен среднему чеку группы В
# H_1: Средний чек группы А НЕ равен среднему чеку группы В
# alpha = 0.05
# ```

# %%
results = st.mannwhitneyu(
    orders[
        np.logical_and(
            orders['group'] == 'A',
            np.logical_not(orders['visitor_id'].isin(abnormal_users)),
            )
    ]['revenue'],
    orders[
        np.logical_and(
            orders['group'] == 'B',
            np.logical_not(orders['visitor_id'].isin(abnormal_users)),
        )
    ]['revenue'],
)

print('P-value -', round(results.pvalue, 5))

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя')
    
print(
    "Относительное различие среднего чека группы В к группе А {0:.3%}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitor_id'].isin(abnormal_users)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitor_id'].isin(abnormal_users)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# P-value - 0.72047
# Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя
# Относительное различие среднего чека группы В к группе А -2.310%

# %% [markdown]
# P-value значительно больше 0.05% - статистически значимых отличий в среднем чеке между группами нет.
#
# После очистки данных от аномальных начений относительная разница в среднем чеке между группой В и группой А уменьшилась на 28,2% (с +25,9% до -2,31%).
#
# И таким образом средний чек группой В стал ниже на 2,31% среднего чека группы А.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера (все отлично)**
#
# Согласен с выводом. После очистки значимых отличий по среднему чеку не появилось.
# </div>

# %% [markdown]
# ### Выводы по результатам провеленного А/В теста

# %% [markdown]
# Примите решение по результатам теста и объясните его. Варианты решений:
# 1. Остановить тест, зафиксировать победу одной из групп.
# 2. Остановить тест, зафиксировать отсутствие различий между группами.
# 3. Продолжить тест.

# %% [markdown]
# Результаты теста по "сырым" даным:
# * Отвергаем нулевую гипотезу о равенстве среднего количества заказов между группами А и В. **Средние не равны, обнаружена статистически значимая разница**. Среднее количество заказов группы В на 13,8% больше среднего количества заказов группы А.
# * Статистически значимых отличий в среднем чеке между группами нет. Кроме того, относительное различие среднего чека между группами 25,9%, не смотря на это статистически значимого отличия не обнаружено.
#
# Результаты теста по "очищенным" даным:
# * Отвергаем гипотезу о равенстве среднего количества заказов между группами А и В. Средние не равны, обнаружена статистически значимая разница. Среднее количество заказов группы В на 17,15% больше среднего количества заказов группы А.
# * После очистки данных от аномальных начений относительная разница в среднем чеке между группой В и группой А уменьшилась на 28,2% (с +25,9% до -2,31%). Таким образом, средний чек группы В стал ниже на 2,31% среднего чека группы А.
#
# Рекомендуется остановит тест в связи с тем, что:
# 1. Имеются ошибки в распределении трафика между группами, что могло сказаться на результатах теста.
# 2. Если не брать во внимание распределение трафика обнаружено, что при очистке данных от аномальных значений среднее количество заказов группы В *стало выше* среднего количества заказов группы А (до очистки на 13,8%, после. на 17,15%).
# 3. Если не брать во внимание распределение трафика обнаружено, что средний чек группы В меньше на -2,31% среднего чека группы А.
#
# Так как цель интернет-магазина - увеличение выручки, то стоит зафиксировать победу группы В, т.к. не смотря на то, что средний чек практически равен среднему чеку группы А, покупать стали чаще, таким образом выручка интернет-магазина возрасла.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# После первичного анализа и предобработки данных сделаны следующие выводы:
# * Предоставлены 3 датафрейма - список гипотез, данные с информацией о заказах, данные о количестве посетителей.
# * Размер датафреймов: список гипотез включает в себя 9 строк и 5 столбцов, данные с информацией о заказах - 1197 строк и 5 столбцов, данные о количестве посетителей - 62 строк и 3 столбцов.
# * Пропущенных значений в датафреймах не обнаружено.
# * Выявлено, что в датафреймах была отображена дата в некорректном формате. Для дальнейшего анализа данные столбцы приведены в корректный формат, так же было приведено название столбцов к стилю Snake Case для удобства дальнейшей работы.
# * Явных дубликатов в датафреймах не обнаружено.
# * Предоставлена информация об истории покупок пользователей и данных о количестве посетителей с 1 августа 2019 г. по 31 августа 2019 г.
#
# **Приоритизаия гипотез**
#
# При оценке гипотез методом ICE наиболее перспективные гипотезы:
# * Запустить акцию, дающую скидку на товар в день рождения.
# * Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей.
# * Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.
# * Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию.
#
# При оценке гипотез методом RICE наиболее перспективные гипотезы:
# * Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.
# * Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа.
# * Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей.
# * Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию.
#
# Имеется 2 совпадения в результатах - "Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей" и "Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию".
#
# Различия в оценке наиболее перспективных гипотезах в разнице параметра Reach (охват пользователей, которых затронет изменение).
#
# В 10 баллов по охвату оценена гипотеза "Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок". По этой причине данная гипотеза лидирует при использовании метода RICE.
#
# Важно учитывать скольких пользователей затронут изменения, в связи с этим имеет смысл проанализировать следующие гипотезы:
# 1. Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок, т.к. данная гипотеза затронет всех пользователей интернет-магазина
# 2. Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа. Не стоит отметать и эту гипотезу, т.к. она затронет 80% пользователей интернет-магазина.
# 3. Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар. Не стоит отметать и эту гипотезу, т.к. она затронет 80% пользователей интернет-магазина.
#
#
# **Анализ результатов А/В теста**
#
# Результаты теста по "сырым" даным:
# * Отвергаем нулевую гипотезу о равенстве среднего количества заказов между группами А и В. **Средние не равны, обнаружена статистически значимая разница**. Среднее количество заказов группы В на 13,8% больше среднего количества заказов группы А.
# * Статистически значимых отличий в среднем чеке между группами нет. Кроме того, относительное различие среднего чека между группами 25,9%, не смотря на это статистически значимого отличия не обнаружено.
#
# Результаты теста по "очищенным" даным:
# * Отвергаем гипотезу о равенстве среднего количества заказов между группами А и В. Средние не равны, обнаружена статистически значимая разница. Среднее количество заказов группы В на 17,15% больше среднего количества заказов группы А.
# * После очистки данных от аномальных начений относительная разница в среднем чеке между группой В и группой А уменьшилась на 28,2% (с +25,9% до -2,31%). Таким образом, средний чек группы В стал ниже на 2,31% среднего чека группы А.
#
# Рекомендуется остановить тест в связи с тем, что:
# 1. Имеются ошибки в распределении трафика между группами, что могло сказаться на результатах теста.
# 2. Если не брать во внимание распределение трафика обнаружено, что при очистке данных от аномальных значений среднее количество заказов группы В *стало выше* среднего количества заказов группы А (до очистки на 13,8%, после. на 17,15%).
# 3. Если не брать во внимание распределение трафика обнаружено, что средний чек группы В меньше на -2,31% среднего чека группы А.
#
# Так как цель интернет-магазина - увеличение выручки, то стоит зафиксировать победу группы В, т.к. не смотря на то, что средний чек практически равен среднему чеку группы А, покупать стали чаще, таким образом, выручка интернет-магазина возрасла.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Комментарий ревьювера (недочет, который нужно доработать)**
#
# 1) Не согласен с решением по тесту. Среднее количество заказов увеличилось при отсутствии значимых изменений по среднему чеку -> выручка увеличилась, так как стали покупать чаще.
#
# 2) Требуется дополнить общий вывод с отображение всех итогов проекта, в том числе по приоритезации гипотез.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> КОММЕНТАРИЙ ОТ УЧЕНИКА:
#     Поняла, затупила))) При увеличении количества заказов пусть и при том же чеке как у группы А итоговая выручка возрасла.
# </b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Комментарий ревьювера v2 (все отлично)**
#
# Основные результаты отражены. Согласен с решением по тесту:)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Комментарий ревьювера (общий вывод)**
#
# Кристина, мне понравилась твоя работа! Выводы хорошо структурированы и достаточно содержательны, умеешь считать перцентили, определять аномалии, качественно проводишь проверку гипотез. Спасибо за четкие комментарии по результатам исследования, аккуратный код и качественное оформление отчета! Это упростило проверку. Для принятия твоей работы нужно исправить критические недочёты:
#
# * дополнить введение;
# * дополнить общий вывод и скорректировать решение по тесту.
#
# В дополнении прикрепляю несколько полезных материалов по теме A/B-тестирования:
#
# * https://medium.com/statistics-experiments
# * https://your-scorpion.ru/ab-tests-check-mathematics/
#
# Жду твою работу!
#
# </div>
